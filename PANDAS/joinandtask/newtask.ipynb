# %%
import pandas as pd
import numpy as np
customers=pd.read_csv("customers_dataset.csv")
orders=pd.read_csv("orders_dataset.csv")
df2=pd.DataFrame(orders)

# %%
df2
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 1. Load orders_dataset.csv into a DataFrame and display the first 5 rows.
df2.head(5)
# Out:
#    OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0     1001         201        Laptop  Electronics         1      65000
# 1     1002         202    Headphones  Electronics         2       2500
# 2     1003         203  Office Chair    Furniture         1       8500
# 3     1004         204      Keyboard  Electronics         3       1800
# 4     1005         205          Desk    Furniture         1      12000
#
#          City     Status  TotalAmount
# 0       Kochi  Completed        65000
# 1    Thrissur  Completed         5000
# 2   Kozhikode    Pending         8500
# 3       Kochi  Completed         5400
# 4  Trivandrum  Cancelled        12000

# %%
# 2. Display the last 5 rows and the shape of the DataFrame.
df2.tail(5)
df2.shape
# Out:
# (15, 9)

# %%
# 3. Display column names, data types, and basic information about the dataset.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      15 non-null     int64
#  1   CustomerID   15 non-null     int64
#  2   Product      15 non-null     object
#  3   Category     15 non-null     object
#  4   Quantity     15 non-null     int64
#  5   UnitPrice    15 non-null     int64
#  6   City         15 non-null     object
#  7   Status       15 non-null     object
#  8   TotalAmount  15 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.2+ KB

# %%
# 4. Find the number of unique products and unique cities.
df2[["Product","City"]].nunique()
# Out:
# Product    15
# City        6
# dtype: int64

# %%
# 5. Display all orders where Category is Electronics.
df2[df2["Category"]=="Electronics"]
# Out:
#     OrderID  CustomerID     Product     Category  Quantity  UnitPrice  \
# 0      1001         201      Laptop  Electronics         1      65000
# 1      1002         202  Headphones  Electronics         2       2500
# 3      1004         204    Keyboard  Electronics         3       1800
# 5      1006         206     Monitor  Electronics         2      14500
# 6      1007         207       Mouse  Electronics         4        900
# 8      1009         209      Webcam  Electronics         2       3200
# 10     1011         211     USB Hub  Electronics         3       1100
# 12     1013         213     Printer  Electronics         1      18500
# 14     1015         215  Microphone  Electronics         2       4500
#
#         City     Status  TotalAmount
# 0      Kochi  Completed        65000
# 1   Thrissur  Completed         5000
# 3      Kochi  Completed         5400
# 5     Kollam  Completed        29000
# 6   Thrissur  Completed         3600
# 8      Kochi  Completed         6400
# ...

# %%
# 6. Display orders where Quantity is greater than 2.
df2[df2["Quantity"]>2]
# Out:
#     OrderID  CustomerID   Product     Category  Quantity  UnitPrice      City  \
# 3      1004         204  Keyboard  Electronics         3       1800     Kochi
# 6      1007         207     Mouse  Electronics         4        900  Thrissur
# 10     1011         211   USB Hub  Electronics         3       1100    Kollam
#
#        Status  TotalAmount
# 3   Completed         5400
# 6   Completed         3600
# 10  Completed         3300

# %%
# 7. Find the number of orders for each Status using value_counts().
df2["Status"].value_counts()
# Out:
# Status
# Completed    10
# Pending       3
# Cancelled     2
# Name: count, dtype: int64

# %%
# 8. Calculate the total revenue of every order using Quantity and UnitPrice.
revenue=df2["Quantity"]*df2["UnitPrice"]
revenue
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 9. Find the total revenue generated from all orders.
revenue.sum()
# Out:
# np.int64(213400)

# %%
# 10. Find the average UnitPrice for each Category using groupby().
df2.groupby("Category")["UnitPrice"].mean()
# Out:
# Category
# Electronics    12444.444444
# Furniture      11100.000000
# Name: UnitPrice, dtype: float64

# %%
# 11. Find the total Quantity sold for each Product Category.
df2.groupby("Category")["Quantity"].sum()
# Out:
# Category
# Electronics    20
# Furniture       7
# Name: Quantity, dtype: int64

# %%
df2
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 12. Find the total revenue generated from each City.
df2.groupby("City").sum("TotalAmount")
# Out:
#             OrderID  CustomerID  Quantity  UnitPrice  TotalAmount
# City
# Kochi          4027         827         7      88500        95300
# Kollam         2017         417         5      15600        32300
# Kottayam       2024         424         2      37500        37500
# Kozhikode      2011         411         2      15500        15500
# Thrissur       3024         624         8       7900        17600
# Trivandrum     2017         417         3      13600        15200

# %%
# 13. Find the average order value for each Status.
df2.groupby("Status")["TotalAmount"].mean()
# Out:
# Status
# Cancelled    20000.000000
# Completed    15470.000000
# Pending       6233.333333
# Name: TotalAmount, dtype: float64

# %%
# 14. Find the maximum TotalAmount for each Category.
df2.groupby("Category")["TotalAmount"].max()
# Out:
# Category
# Electronics    65000
# Furniture      28000
# Name: TotalAmount, dtype: int64

# %%
# 15. Sort the DataFrame by TotalAmount from highest to lowest.
df2.sort_values("TotalAmount",ascending=False)
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 5      1006         206       Monitor  Electronics         2      14500
# 13     1014         214          Sofa    Furniture         1      28000
# 12     1013         213       Printer  Electronics         1      18500
# 4      1005         205          Desk    Furniture         1      12000
# 9      1010         210   Study Table    Furniture         1       9500
# 14     1015         215    Microphone  Electronics         2       4500
# 2      1003         203  Office Chair    Furniture         1       8500
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 3      1004         204      Keyboard  Electronics         3       1800
# 1      1002         202    Headphones  Electronics         2       2500
# ...

# %%
# 16. Display the top 5 highest-value orders.
df2.sort_values("TotalAmount",ascending=False).head(5)
# Out:
#     OrderID  CustomerID  Product     Category  Quantity  UnitPrice  \
# 0      1001         201   Laptop  Electronics         1      65000
# 5      1006         206  Monitor  Electronics         2      14500
# 13     1014         214     Sofa    Furniture         1      28000
# 12     1013         213  Printer  Electronics         1      18500
# 4      1005         205     Desk    Furniture         1      12000
#
#           City     Status  TotalAmount
# 0        Kochi  Completed        65000
# 5       Kollam  Completed        29000
# 13    Kottayam  Cancelled        28000
# 12       Kochi  Completed        18500
# 4   Trivandrum  Cancelled        12000

# %%
# 17. Find the product with the highest TotalAmount.
df2.sort_values("TotalAmount",ascending=False).head(1)
# Out:
#    OrderID  CustomerID Product     Category  Quantity  UnitPrice   City  \
# 0     1001         201  Laptop  Electronics         1      65000  Kochi
#
#       Status  TotalAmount
# 0  Completed        65000

# %%
# 18. Count how many orders were placed in each City and Status combination using groupby().
df2.groupby(["Status","City"]).count()
# Out:
#                       OrderID  CustomerID  Product  Category  Quantity  \
# Status    City
# Cancelled Kottayam          1           1        1         1         1
#           Trivandrum        1           1        1         1         1
# Completed Kochi             4           4        4         4         4
#           Kollam            2           2        2         2         2
#           Kottayam          1           1        1         1         1
#           Thrissur          3           3        3         3         3
# Pending   Kozhikode         2           2        2         2         2
#           Trivandrum        1           1        1         1         1
#
#                       UnitPrice  TotalAmount
# Status    City
# Cancelled Kottayam            1            1
#           Trivandrum          1            1
# Completed Kochi               4            4
#           Kollam              2            2
#           Kottayam            1            1
# ...

# %%
# 19. Find the total revenue from Completed orders only.
df2[df2["Status"] == "Completed"]["TotalAmount"].sum()

# %%
# 20. Find cities whose total revenue is greater than 20000 using groupby() and a condition.
revenue = df2.groupby("City")["TotalAmount"].sum()
revenue[revenue > 20000]
# Out:
# City
# Kochi       95300
# Kollam      32300
# Kottayam    37500
# Name: TotalAmount, dtype: int64

# %%
# 21. Create a new column PriceLevel: 'High' if UnitPrice >= 10000, otherwise 'Normal'.
df2["PriceLevel"]=np.where(df2["UnitPrice"]>=10000,"High","Normal")
df2
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 22. Create a new column OrderValueLevel: 'Large' if TotalAmount >= 15000, otherwise 'Regular'.
df2["OrderValueLevel"]=np.where(df2["TotalAmount"]>=15000,"Large","Regular")
df2
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 23. Find the average Quantity for Electronics and Furniture separately.
df2.groupby("Category")["Quantity"].mean()
# Out:
# Category
# Electronics    2.222222
# Furniture      1.166667
# Name: Quantity, dtype: float64

# %%
# 24. Find the category with the highest total revenue.
df2.groupby("Category")["TotalAmount"].sum().sort_values(ascending=False).head(1)
# Out:
# Category
# Electronics    145200
# Name: TotalAmount, dtype: int64

# %%
# 25. Use groupby() with multiple aggregations to calculate total quantity, average unit price, and total revenue for
# each Category.
df2.groupby("Category").agg({
    "Quantity": "sum",
    "UnitPrice": "mean",
    "TotalAmount": "sum"
})
# Out:
#              Quantity     UnitPrice  TotalAmount
# Category
# Electronics        20  12444.444444       145200
# Furniture           7  11100.000000        68200

# %%
# 26. Load customers_dataset.csv into a second DataFrame.
df1=pd.DataFrame(customers)

# %%
# 27. Perform an inner join between orders and customers using CustomerID.
result=pd.merge(df2,df1,on="CustomerID",how="inner")
result
# Out:
#     OrderID  CustomerID       Product     Category  Quantity  UnitPrice  \
# 0      1001         201        Laptop  Electronics         1      65000
# 1      1002         202    Headphones  Electronics         2       2500
# 2      1003         203  Office Chair    Furniture         1       8500
# 3      1004         204      Keyboard  Electronics         3       1800
# 4      1005         205          Desk    Furniture         1      12000
# 5      1006         206       Monitor  Electronics         2      14500
# 6      1007         207         Mouse  Electronics         4        900
# 7      1008         208     Bookshelf    Furniture         1       7000
# 8      1009         209        Webcam  Electronics         2       3200
# 9      1010         210   Study Table    Furniture         1       9500
# 10     1011         211       USB Hub  Electronics         3       1100
# 11     1012         212    Table Lamp    Furniture         2       1600
# ...

# %%
# 28. Select and display CustomerName, Product, Quantity, TotalAmount, Membership, and City after the join.
result[["CustomerName","Product","Quantity","TotalAmount","Membership","City_x"]]
# Out:
#    CustomerName       Product  Quantity  TotalAmount Membership      City_x
# 0         Akhil        Laptop         1        65000       Gold       Kochi
# 1        Anjali    Headphones         2         5000     Silver    Thrissur
# 2         Rahul  Office Chair         1         8500     Bronze   Kozhikode
# 3         Meera      Keyboard         3         5400       Gold       Kochi
# 4        Vishnu          Desk         1        12000     Silver  Trivandrum
# 5         Sneha       Monitor         2        29000       Gold      Kollam
# 6         Arjun         Mouse         4         3600     Bronze    Thrissur
# 7        Devika     Bookshelf         1         7000     Silver   Kozhikode
# 8        Nikhil        Webcam         2         6400       Gold       Kochi
# 9        Athira   Study Table         1         9500       Gold    Kottayam
# 10     Sreehari       USB Hub         3         3300     Silver      Kollam
# ...

# %%
# 29. Find the total revenue generated by each customer.
result.groupby(["CustomerID", "CustomerName"])["TotalAmount"].sum()
# Out:
# CustomerID  CustomerName
# 201         Akhil           65000
# 202         Anjali           5000
# 203         Rahul            8500
# 204         Meera            5400
# 205         Vishnu          12000
# 206         Sneha           29000
# 207         Arjun            3600
# 208         Devika           7000
# 209         Nikhil           6400
# 210         Athira           9500
# 211         Sreehari         3300
# 212         Fathima          3200
# 213         Joel            18500
# 214         Gokul           28000
# 215         Keerthana        9000
# Name: TotalAmount, dtype: int64

# %%
# 30. Find the total revenue generated by each Membership type.
result.groupby(["Membership"])["TotalAmount"].sum()
# Out:
# Membership
# Bronze     15300
# Gold      142800
# Silver     55300
# Name: TotalAmount, dtype: int64

# %%
# 31. Find the average order value for each Membership type.
result.groupby(["Membership"])["TotalAmount"].mean()
# Out:
# Membership
# Bronze     5100.0
# Gold      20400.0
# Silver    11060.0
# Name: TotalAmount, dtype: float64

# %%
# 32. Find the total quantity purchased by customers from each City.
result.groupby("City_x")["Quantity"].sum()
# Out:
# City_x
# Kochi         7
# Kollam        5
# Kottayam      2
# Kozhikode     2
# Thrissur      8
# Trivandrum    3
# Name: Quantity, dtype: int64

# %%
# 33. Find the number of orders made by each Gender.
result.groupby("Gender")["OrderID"].count()
# Out:
# Gender
# Female    7
# Male      8
# Name: OrderID, dtype: int64

# %%
# 34. Find the average customer age for each Membership type.
result.groupby("Membership")["Age"].mean()
# Out:
# Membership
# Bronze    29.333333
# Gold      27.571429
# Silver    31.000000
# Name: Age, dtype: float64

# %%
# 35. Find the customer who generated the highest total revenue.
result.groupby("CustomerName")["TotalAmount"].sum().sort_values(ascending=False).head(1)
# Out:
# CustomerName
# Akhil    65000
# Name: TotalAmount, dtype: int64

# %% [markdown]
# PART C

# %%
# 36. After joining the datasets, display only Gold members who placed Completed orders.
result[(result["Membership"]=="Gold") & (result["Status"]=="Completed")]
# Out:
#     OrderID  CustomerID      Product     Category  Quantity  UnitPrice  \
# 0      1001         201       Laptop  Electronics         1      65000
# 3      1004         204     Keyboard  Electronics         3       1800
# 5      1006         206      Monitor  Electronics         2      14500
# 8      1009         209       Webcam  Electronics         2       3200
# 9      1010         210  Study Table    Furniture         1       9500
# 12     1013         213      Printer  Electronics         1      18500
# 14     1015         215   Microphone  Electronics         2       4500
#
#       City_x     Status  TotalAmount CustomerName  Age  Gender Membership  \
# 0      Kochi  Completed        65000        Akhil   24    Male       Gold
# 3      Kochi  Completed         5400        Meera   29  Female       Gold
# 5     Kollam  Completed        29000        Sneha   26  Female       Gold
# 8      Kochi  Completed         6400       Nikhil   28    Male       Gold
# ...

# %%
# 37. Find Gold members whose TotalAmount is greater than 10000.
result[(result["Membership"]=="Gold") & (result["TotalAmount"]>10000)]
# Out:
#     OrderID  CustomerID  Product     Category  Quantity  UnitPrice  City_x  \
# 0      1001         201   Laptop  Electronics         1      65000   Kochi
# 5      1006         206  Monitor  Electronics         2      14500  Kollam
# 12     1013         213  Printer  Electronics         1      18500   Kochi
#
#        Status  TotalAmount CustomerName  Age  Gender Membership  City_y
# 0   Completed        65000        Akhil   24    Male       Gold   Kochi
# 5   Completed        29000        Sneha   26  Female       Gold  Kollam
# 12  Completed        18500         Joel   29    Male       Gold   Kochi

# %%
# 38. Find customers older than 30 who placed Completed orders.
result[(result["Age"]>30)&(result["Status"]=="Completed")]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, Product, Category, Quantity, UnitPrice, City_x, Status, TotalAmount, CustomerName, Age, Gender, Membership, City_y]
# Index: []

# %%
# 39. Find Female customers from Kochi and display their order details.
result[(result["Gender"]=="Female")&(result["City_x"]=="Kochi")]
# Out:
#    OrderID  CustomerID   Product     Category  Quantity  UnitPrice City_x  \
# 3     1004         204  Keyboard  Electronics         3       1800  Kochi
#
#       Status  TotalAmount CustomerName  Age  Gender Membership City_y
# 3  Completed         5400        Meera   29  Female       Gold  Kochi

# %%
# 40. Find Male customers who purchased Electronics products.
result[(result["Gender"]=="Male")&(result["Category"]=="Electronics")]
# Out:
#     OrderID  CustomerID  Product     Category  Quantity  UnitPrice    City_x  \
# 0      1001         201   Laptop  Electronics         1      65000     Kochi
# 6      1007         207    Mouse  Electronics         4        900  Thrissur
# 8      1009         209   Webcam  Electronics         2       3200     Kochi
# 10     1011         211  USB Hub  Electronics         3       1100    Kollam
# 12     1013         213  Printer  Electronics         1      18500     Kochi
#
#        Status  TotalAmount CustomerName  Age Gender Membership    City_y
# 0   Completed        65000        Akhil   24   Male       Gold     Kochi
# 6   Completed         3600        Arjun   23   Male     Bronze  Thrissur
# 8   Completed         6400       Nikhil   28   Male       Gold     Kochi
# 10  Completed         3300     Sreehari   25   Male     Silver    Kollam
# 12  Completed        18500         Joel   29   Male       Gold     Kochi

# %%
# 41. Find Silver members whose Quantity is greater than 1.
result[(result["Membership"]=="Silver")&(result["Quantity"]>1)]
# Out:
#     OrderID  CustomerID     Product     Category  Quantity  UnitPrice  \
# 1      1002         202  Headphones  Electronics         2       2500
# 10     1011         211     USB Hub  Electronics         3       1100
#
#       City_x     Status  TotalAmount CustomerName  Age  Gender Membership  \
# 1   Thrissur  Completed         5000       Anjali   27  Female     Silver
# 10    Kollam  Completed         3300     Sreehari   25    Male     Silver
#
#       City_y
# 1   Thrissur
# 10    Kollam

# %%
# 42. Find customers from Thrissur whose orders have TotalAmount greater than 5000.
result[(result["City_x"] == "Thrissur") & (result["TotalAmount"] > 5000)]
# Out:
#     OrderID  CustomerID     Product     Category  Quantity  UnitPrice  \
# 14     1015         215  Microphone  Electronics         2       4500
#
#       City_x     Status  TotalAmount CustomerName  Age  Gender Membership  \
# 14  Thrissur  Completed         9000    Keerthana   27  Female       Gold
#
#       City_y
# 14  Thrissur

# %%
# 43. Find Gold members whose total spending is greater than 15000 using groupby() and a condition.
gold_spending = result[result["Membership"] == "Gold"].groupby("CustomerName")["TotalAmount"].sum()
gold_spending[gold_spending > 15000]
# Out:
# CustomerName
# Akhil    65000
# Joel     18500
# Sneha    29000
# Name: TotalAmount, dtype: int64

# %%
# 44. Find the total revenue of Completed orders for each Membership type.
result[result["Status"] == "Completed"].groupby("Membership")["TotalAmount"].sum()
# Out:
# Membership
# Bronze      3600
# Gold      142800
# Silver      8300
# Name: TotalAmount, dtype: int64

# %%
# 45. Find the total revenue generated by each City for Gold members only.
result[result["Membership"] == "Gold"].groupby("City_x")["TotalAmount"].sum()
# Out:
# City_x
# Kochi       95300
# Kollam      29000
# Kottayam     9500
# Thrissur     9000
# Name: TotalAmount, dtype: int64

# %%
# 46. Find the average TotalAmount for Male and Female customers separately.
result.groupby("Gender")["TotalAmount"].mean()
# Out:
# Gender
# Female     9728.571429
# Male      18162.500000
# Name: TotalAmount, dtype: float64

# %%
# 47. Find customers who have at least one Cancelled order.
result[result["Status"] == "Cancelled"]
# Out:
#     OrderID  CustomerID Product   Category  Quantity  UnitPrice      City_x  \
# 4      1005         205    Desk  Furniture         1      12000  Trivandrum
# 13     1014         214    Sofa  Furniture         1      28000    Kottayam
#
#        Status  TotalAmount CustomerName  Age Gender Membership      City_y
# 4   Cancelled        12000       Vishnu   35   Male     Silver  Trivandrum
# 13  Cancelled        28000        Gokul   36   Male     Silver    Kottayam

# %%
# 48. Find customers who purchased Furniture and have Gold membership.
result[(result["Category"] == "Furniture") & (result["Membership"] == "Gold")]
# Out:
#    OrderID  CustomerID      Product   Category  Quantity  UnitPrice    City_x  \
# 9     1010         210  Study Table  Furniture         1       9500  Kottayam
#
#       Status  TotalAmount CustomerName  Age  Gender Membership    City_y
# 9  Completed         9500       Athira   30  Female       Gold  Kottayam

# %%
# 49. Find the top 3 customers based on total Completed-order revenue.
completed = result[result["Status"] == "Completed"]
completed.groupby("CustomerName")["TotalAmount"].sum().sort_values(ascending=False).head(3)

# %%
# 50. Create a final customer summary containing CustomerName, Membership, City, number of orders, total
# quantity purchased, and total revenue.
summary = result.groupby(["CustomerName", "Membership", "City_x"]).agg(
    NumberOfOrders=("OrderID", "count"),
    TotalQuantity=("Quantity", "sum"),
    TotalRevenue=("TotalAmount", "sum")
)

summary
# Out:
#                                     NumberOfOrders  TotalQuantity  \
# CustomerName Membership City_x
# Akhil        Gold       Kochi                    1              1
# Anjali       Silver     Thrissur                 1              2
# Arjun        Bronze     Thrissur                 1              4
# Athira       Gold       Kottayam                 1              1
# Devika       Silver     Kozhikode                1              1
# Fathima      Bronze     Trivandrum               1              2
# Gokul        Silver     Kottayam                 1              1
# Joel         Gold       Kochi                    1              1
# Keerthana    Gold       Thrissur                 1              2
# Meera        Gold       Kochi                    1              3
# Nikhil       Gold       Kochi                    1              2
# Rahul        Bronze     Kozhikode                1              1
# Sneha        Gold       Kollam                   1              2
# ...
